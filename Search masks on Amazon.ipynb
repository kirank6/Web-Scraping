# %%
from lxml import html
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from IPython.display import Image

# %%
driver = webdriver.Chrome('C:/Users/Nani/Documents/chromedriver_win32/chromedriver')

# %%
driver.get('https://www.amazon.com/')

# %%
title = driver.title
title
# Out:
# 'Amazon.com: Online Shopping for Electronics, Apparel, Computers, Books, DVDs & more'

# %%
content = driver.page_source
#print(content)

# %%
search = driver.find_element_by_id("twotabsearchtextbox")
search.send_keys("masks")

# %%
driver.find_element_by_id("twotabsearchtextbox").submit()

# %%
new_content =driver.current_url
print(new_content)
# Out:
# https://www.amazon.com/s?k=masks&ref=nb_sb_noss_1

# %%
driver.save_screenshot('masks_amazon.png')
# Out:
# True

# %%
Image('masks_amazon.png')

# %%
#print(driver.page_source)
